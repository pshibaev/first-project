# %% [markdown]
# **Проект: Обучение с учителем: качество модели**

# %% [markdown]
# **Описание исследования.**

# %% [markdown]
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.

# %% [markdown]
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.

# %% [markdown]
# **Цель исследования.**

# %% [markdown]
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# **Задачи исследования.**

# %% [markdown]
# - Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
# - В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
# - Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.
#
# Руководство одобрило описание решения, и вам, как специалисту по DS, нужно его реализовать.

# %% [markdown]
# **Исходные данные.**

# %% [markdown]
# `market_file.csv`
# Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
# - `id` — номер покупателя в корпоративной базе данных.
# - `Покупательская активность` — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - `Тип сервиса` — уровень сервиса, например «премиум» и «стандарт».
# - `Разрешить сообщать` — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# - `Маркет_актив_6_мес` — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# - `Маркет_актив_тек_мес` — количество маркетинговых коммуникаций в текущем месяце.
# - `Длительность` — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - `Акционные_покупки` — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - `Популярная_категория` — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - `Средний_просмотр_категорий_за_визит` — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# - `Неоплаченные_продукты_штук_квартал` — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - `Ошибка_сервиса` — число сбоев, которые коснулись покупателя во время посещения сайта.
# - `Страниц_за_визит` — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.

# %% [markdown]
# `market_money.csv`
# Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# - `id` — номер покупателя в корпоративной базе данных.
# - `Период` — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
# - `Выручка` — сумма выручки за период.

# %% [markdown]
# `market_time.csv`
# Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# - `id` — номер покупателя в корпоративной базе данных.
# - `Период` — название периода, во время которого зафиксировано общее время.
# - `минут` — значение времени, проведённого на сайте, в минутах.

# %% [markdown]
# `money.csv`
# Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
# - `id` — номер покупателя в корпоративной базе данных.
# - `Прибыль` — значение прибыли.

# %% [markdown]
# **Данное исследование разделим на несколько частей.**

# %% [markdown]
# ***1. Загрузка данных***

# %% [markdown]
# ***2. Предобработка данных***

# %% [markdown]
# ***3. Исследовательский анализ данных***

# %% [markdown]
# ***4. Объединение таблиц***

# %% [markdown]
# ***5. Корреляционный анализ***

# %% [markdown]
# ***6. Использование пайплайнов***

# %% [markdown]
# ***7. Анализ важности признаков***

# %% [markdown]
# ***8. Сегментация покупателей***

# %% [markdown]
# ***9. Общий вывод***

# %%
import os

import numpy as np
import pandas as pd
pd.set_option('display.float_format', '{:,.2f}'.format)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install -q shap
import shap

# !pip install -q missingno
import missingno as msno

# !pip install -q --upgrade scikit-learn

# загружаем класс pipeline
from sklearn.pipeline import Pipeline

# загружаем классы для подготовки данных
from sklearn.preprocessing import (LabelEncoder, OneHotEncoder, 
    OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler)
from sklearn.compose import ColumnTransformer

# загружаем класс для работы с пропусками
from sklearn.impute import SimpleImputer

# загружаем функцию для работы с метриками
from sklearn.metrics import roc_auc_score

# импортируем класс RandomizedSearchCV
from sklearn.model_selection import (RandomizedSearchCV, 
    train_test_split)

# загружаем нужные модели
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

RANDOM_STATE = 42
TEST_SIZE = 0.25

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# ### Загрузите данные.

# %% [markdown]
# Файлы `market_file.csv`, `market_money.csv`, `market_time.csv`, `money.csv` доступны по ссылкам в описании данных или через пути к ним:

# %%
def load_dataframe(pth1, pth2, sep, decimal='.'):
    if os.path.exists(pth1):
        df = pd.read_csv(pth1, sep=sep, index_col=0, decimal=decimal)
        print('Данные загружены локально.')
        return df
    else:
        try:
            df = pd.read_csv(pth2, sep=sep, index_col=0, decimal=decimal)
            print('Данные загружены с сервера.')
            return df
        except:
            print('Данные не загружены')
            return None

# %%
market_file = load_dataframe('./datasets/market_file.csv', 'https://code.s3.yandex.net/datasets/market_file.csv', ',')
# Out:
# Данные загружены с сервера.

# %%
market_money = load_dataframe('./datasets/market_money.csv', 'https://code.s3.yandex.net/datasets/market_money.csv', ',')
# Out:
# Данные загружены с сервера.

# %%
market_time = load_dataframe('./datasets/market_time.csv', 'https://code.s3.yandex.net/datasets/market_time.csv', ',')
# Out:
# Данные загружены с сервера.

# %%
money = load_dataframe('./datasets/money.csv', 'https://code.s3.yandex.net/datasets/money.csv', ';', ',')
# Out:
# Данные загружены с сервера.

# %% [markdown]
# ### Проверьте, что данные в таблицах соответствуют описанию.

# %% [markdown]
# Исследованием и объединением данных вы займётесь позже.

# %%
print(market_file.shape)
market_file.head(5)
# Out:
# (1300, 12)
#        Покупательская активность Тип сервиса Разрешить сообщать  \
# id
# 215348                 Снизилась     премиум                 да
# 215349                 Снизилась     премиум                 да
# 215350                 Снизилась   стандартт                нет
# 215351                 Снизилась   стандартт                 да
# 215352                 Снизилась   стандартт                нет
#
#         Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# id
# 215348                3.40                     5           121
# 215349                4.40                     4           819
# 215350                4.90                     3           539
# 215351                3.20                     5           896
# 215352                5.10                     3          1064
#
#         Акционные_покупки Популярная_категория  \
# id
# 215348               0.00     Товары для детей
# 215349               0.75     Товары для детей
# ...

# %%
print(market_money.shape)
market_money.head(5)
# Out:
# (3900, 2)
#                      Период  Выручка
# id
# 215348  препредыдущий_месяц     0.00
# 215348        текущий_месяц 3,293.10
# 215348     предыдущий_месяц     0.00
# 215349  препредыдущий_месяц 4,472.00
# 215349        текущий_месяц 4,971.60

# %%
print(market_time.shape)
market_time.head(5)
# Out:
# (2600, 2)
#                   Период  минут
# id
# 215348     текущий_месяц     14
# 215348  предыдцщий_месяц     13
# 215349     текущий_месяц     10
# 215349  предыдцщий_месяц     12
# 215350     текущий_месяц     13

# %%
print(money.shape)
money.head(5)
# Out:
# (1300, 1)
#         Прибыль
# id
# 215348     0.98
# 215349     4.16
# 215350     3.13
# 215351     4.87
# 215352     4.21

# %% [markdown]
# **Вывод по разделу:**

# %% [markdown]
# - данные в таблицах загружены и соответствуют описанию.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Проведите необходимую предобработку данных. Названия столбцов можно оставить кириллическими.

# %%
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1300 entries, 215348 to 216647
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Прибыль  1300 non-null   float64
# dtypes: float64(1)
# memory usage: 20.3 KB

# %% [markdown]
# Признак прибль необходимо преобразовать из строки в число

# %%
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1300 entries, 215348 to 216647
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Прибыль  1300 non-null   float64
# dtypes: float64(1)
# memory usage: 20.3 KB

# %%
money.reset_index().duplicated().sum()
# Out:
# 0

# %%
market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2600 entries, 215348 to 216647
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Период  2600 non-null   object
#  1   минут   2600 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 60.9+ KB

# %%
market_time.reset_index().duplicated().sum()
# Out:
# 0

# %%
market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3900 entries, 215348 to 216647
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Период   3900 non-null   object
#  1   Выручка  3900 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 91.4+ KB

# %%
market_money.reset_index().duplicated().sum()
# Out:
# 0

# %%
market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1300 entries, 215348 to 216647
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Покупательская активность            1300 non-null   object
#  1   Тип сервиса                          1300 non-null   object
#  2   Разрешить сообщать                   1300 non-null   object
#  3   Маркет_актив_6_мес                   1300 non-null   float64
#  4   Маркет_актив_тек_мес                 1300 non-null   int64
#  5   Длительность                         1300 non-null   int64
#  6   Акционные_покупки                    1300 non-null   float64
#  7   Популярная_категория                 1300 non-null   object
#  8   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  9   Неоплаченные_продукты_штук_квартал   1300 non-null   int64
#  10  Ошибка_сервиса                       1300 non-null   int64
# ...

# %%
market_file.reset_index().duplicated().sum()
# Out:
# 0

# %% [markdown]
# Необходимо заменить пробелы в названиях признаков на нижнее подчеркивание

# %%
new_columns = {
    'Покупательская активность' : 'Покупательская_активность',
    'Тип сервиса' : 'Тип_сервиса',
    'Разрешить сообщать' : 'Разрешить_сообщать'
}

# %%
market_file.rename(columns=new_columns, inplace=True)

# %%
market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1300 entries, 215348 to 216647
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Покупательская_активность            1300 non-null   object
#  1   Тип_сервиса                          1300 non-null   object
#  2   Разрешить_сообщать                   1300 non-null   object
#  3   Маркет_актив_6_мес                   1300 non-null   float64
#  4   Маркет_актив_тек_мес                 1300 non-null   int64
#  5   Длительность                         1300 non-null   int64
#  6   Акционные_покупки                    1300 non-null   float64
#  7   Популярная_категория                 1300 non-null   object
#  8   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  9   Неоплаченные_продукты_штук_квартал   1300 non-null   int64
#  10  Ошибка_сервиса                       1300 non-null   int64
# ...

# %% [markdown]
# **Вывод по разделу:**

# %% [markdown]
# - пропуски отсутствуют
# - аномалии отсутствуют
# - явные дубликаты отсутствуют
# - столбцы приведены к соответствующим типам

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Проведите исследовательский анализ данных из каждой таблицы. Отберите клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период. Оформите выводы по результатам шага.

# %%
money.describe()
# Out:
#        Прибыль
# count 1,300.00
# mean      4.00
# std       1.01
# min       0.86
# 25%       3.30
# 50%       4.04
# 75%       4.67
# max       7.43

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
fig.suptitle('Среднемесячное значения (за 3 месяца) прибыли на клиента')
axes[0].hist(money['Прибыль'])
axes[0].set_xlabel('в ден. ед.')
axes[1].boxplot(money['Прибыль'], vert=False)
axes[1].set_title('')
axes[1].set_xlabel('в ден. ед.')
plt.show()

# %%
market_time.describe()
# Out:
#          минут
# count 2,600.00
# mean     13.34
# std       4.08
# min       4.00
# 25%      10.00
# 50%      13.00
# 75%      16.00
# max      23.00

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
fig.suptitle('Временя которое покупатель провёл на сайте в течение периода')
axes[0].hist(market_time['минут'])
axes[0].set_xlabel('минут')
axes[1].boxplot(market_time['минут'], vert=False)
axes[1].set_title('')
axes[1].set_xlabel('минут')
plt.show()

# %%
market_time['Период'].value_counts()
# Out:
# Период
# текущий_месяц       1300
# предыдцщий_месяц    1300
# Name: count, dtype: int64

# %% [markdown]
# Необходимо исправить ошибку в категории `предыдцщий_месяц`

# %%
market_time['Период'] = market_time['Период'].str.replace('предыдцщий_месяц', 'предыдущий_месяц')

# %%
market_money.describe()
# Out:
#          Выручка
# count   3,900.00
# mean    5,025.70
# std     1,777.70
# min         0.00
# 25%     4,590.15
# 50%     4,957.50
# 75%     5,363.00
# max   106,862.20

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
fig.suptitle('Значение выручки, которую получает магазин с покупателя за период')
axes[0].hist(market_money['Выручка'])
axes[0].set_xlabel('в ден. ед.')
axes[1].boxplot(market_money['Выручка'], vert=False)
axes[1].set_title('')
axes[1].set_xlabel('в ден. ед.')
plt.show()

# %% [markdown]
# есть явный выброс на 106 и 0 тыс. удаляем

# %%
market_money = market_money[(market_money['Выручка'] < 100000) & (market_money['Выручка'] > 0)]

# %%
market_money.describe()
# Out:
#        Выручка
# count 3,893.00
# mean  5,007.28
# std     679.72
# min   2,758.70
# 25%   4,592.00
# 50%   4,959.00
# 75%   5,363.00
# max   7,799.40

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
fig.suptitle('Значение выручки, которую получает магазин с покупателя за период')
axes[0].hist(market_money['Выручка'])
axes[0].set_xlabel('в ден. ед.')
axes[1].boxplot(market_money['Выручка'], vert=False)
axes[1].set_title('')
axes[1].set_xlabel('в ден. ед.')
plt.show()

# %%
market_money['Период'].value_counts()
# Out:
# Период
# текущий_месяц          1299
# препредыдущий_месяц    1297
# предыдущий_месяц       1297
# Name: count, dtype: int64

# %%
market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1300 entries, 215348 to 216647
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Покупательская_активность            1300 non-null   object
#  1   Тип_сервиса                          1300 non-null   object
#  2   Разрешить_сообщать                   1300 non-null   object
#  3   Маркет_актив_6_мес                   1300 non-null   float64
#  4   Маркет_актив_тек_мес                 1300 non-null   int64
#  5   Длительность                         1300 non-null   int64
#  6   Акционные_покупки                    1300 non-null   float64
#  7   Популярная_категория                 1300 non-null   object
#  8   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  9   Неоплаченные_продукты_штук_квартал   1300 non-null   int64
#  10  Ошибка_сервиса                       1300 non-null   int64
# ...

# %%
market_file['Покупательская_активность'].value_counts()
# Out:
# Покупательская_активность
# Прежний уровень    802
# Снизилась          498
# Name: count, dtype: int64

# %%
market_file_low = market_file[market_file['Покупательская_активность'] == 'Снизилась'].copy()

# %%
market_file_norm = market_file[market_file['Покупательская_активность'] == 'Прежний уровень'].copy()

# %%
market_file.describe()
# Out:
#        Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# count            1,300.00              1,300.00      1,300.00
# mean                 4.25                  4.01        601.90
# std                  1.01                  0.70        249.86
# min                  0.90                  3.00        110.00
# 25%                  3.70                  4.00        405.50
# 50%                  4.20                  4.00        606.00
# 75%                  4.90                  4.00        806.00
# max                  6.60                  5.00      1,079.00
#
#        Акционные_покупки  Средний_просмотр_категорий_за_визит  \
# count           1,300.00                             1,300.00
# mean                0.32                                 3.27
# std                 0.25                                 1.36
# min                 0.00                                 1.00
# 25%                 0.17                                 2.00
# ...

# %%
market_file_low.describe()
# Out:
#        Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# count              498.00                498.00        498.00
# mean                 3.74                  4.01        619.88
# std                  1.05                  0.71        239.94
# min                  0.90                  3.00        110.00
# 25%                  3.10                  4.00        449.00
# 50%                  3.90                  4.00        634.50
# 75%                  4.40                  5.00        811.00
# max                  6.60                  5.00      1,079.00
#
#        Акционные_покупки  Средний_просмотр_категорий_за_визит  \
# count             498.00                               498.00
# mean                0.45                                 2.63
# std                 0.31                                 1.23
# min                 0.00                                 1.00
# 25%                 0.24                                 2.00
# ...

# %%
market_file_norm.describe()
# Out:
#        Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# count              802.00                802.00        802.00
# mean                 4.57                  4.01        590.73
# std                  0.85                  0.69        255.33
# min                  0.90                  3.00        121.00
# 25%                  4.00                  4.00        382.50
# 50%                  4.40                  4.00        590.00
# 75%                  5.28                  4.00        798.75
# max                  6.60                  5.00      1,061.00
#
#        Акционные_покупки  Средний_просмотр_категорий_за_визит  \
# count             802.00                               802.00
# mean                0.24                                 3.67
# std                 0.16                                 1.28
# min                 0.11                                 1.00
# 25%                 0.15                                 3.00
# ...

# %%
# market_file['Маркет_актив_6_мес'].describe()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))
fig.suptitle('Cреднемесячное значение (за 6 мес) показов рекламы и прочее на клиента')
axes[0].hist(market_file_low['Маркет_актив_6_мес'], alpha=0.5, label='Снизилась')
axes[0].hist(market_file_norm['Маркет_актив_6_мес'], alpha=0.5, label='Прежний уровень')
axes[0].set_xlabel('в штуках')
axes[0].legend(loc='upper left')
axes[1].boxplot(market_file_low['Маркет_актив_6_мес'], vert=False)
axes[2].boxplot(market_file_norm['Маркет_актив_6_мес'], vert=False)
axes[1].set_title('')
axes[1].set_xlabel('Снизилась')
axes[2].set_title('')
axes[2].set_xlabel('Прежний уровень')
plt.show()

# %%
# market_file['Маркет_актив_тек_мес'].describe()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))
fig.suptitle('Cреднемесячное значение (за тек. месяц) показов рекламы и прочее на клиента')
axes[0].hist(market_file_low['Маркет_актив_тек_мес'], alpha=0.5, label='Снизилась')
axes[0].hist(market_file_norm['Маркет_актив_тек_мес'], alpha=0.5, label='Прежний уровень')
axes[0].set_xlabel('в штуках')
axes[0].legend(loc='upper left')
axes[1].boxplot(market_file_low['Маркет_актив_тек_мес'], vert=False)
axes[2].boxplot(market_file_norm['Маркет_актив_тек_мес'], vert=False)
axes[1].set_title('')
axes[1].set_xlabel('Снизилась')
axes[2].set_title('')
axes[2].set_xlabel('Прежний уровень')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))
fig.suptitle('Дней прошедших с момента регистрации покупателя на сайте')
axes[0].hist(market_file_low['Длительность'], alpha=0.5, label='Снизилась')
axes[0].hist(market_file_norm['Длительность'], alpha=0.5, label='Прежний уровень')
axes[0].set_xlabel('в штуках')
axes[0].legend(loc='upper left')
axes[1].boxplot(market_file_low['Длительность'], vert=False)
axes[2].boxplot(market_file_norm['Длительность'], vert=False)
axes[1].set_title('')
axes[1].set_xlabel('Снизилась')
axes[2].set_title('')
axes[2].set_xlabel('Прежний уровень')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))
fig.suptitle('Среднемесячная доля покупок по акции за последние 6 месяцев')
axes[0].hist(market_file_low['Акционные_покупки'], alpha=0.5, label='Снизилась')
axes[0].hist(market_file_norm['Акционные_покупки'], alpha=0.5, label='Прежний уровень')
axes[0].set_xlabel('в штуках')
axes[0].legend(loc='upper right')
axes[1].boxplot(market_file_low['Акционные_покупки'], vert=False)
axes[2].boxplot(market_file_norm['Акционные_покупки'], vert=False)
axes[1].set_title('')
axes[1].set_xlabel('Снизилась')
axes[2].set_title('')
axes[2].set_xlabel('Прежний уровень')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))
fig.suptitle('Среднемесячное значение просмотренных категорий за визит в течение последнего месяца')
axes[0].hist(market_file_low['Средний_просмотр_категорий_за_визит'], alpha=0.5, label='Снизилась')
axes[0].hist(market_file_norm['Средний_просмотр_категорий_за_визит'], alpha=0.5, label='Прежний уровень')
axes[0].set_xlabel('в штуках')
axes[0].legend(loc='upper left')
axes[1].boxplot(market_file_low['Средний_просмотр_категорий_за_визит'], vert=False)
axes[2].boxplot(market_file_norm['Средний_просмотр_категорий_за_визит'], vert=False)
axes[1].set_title('')
axes[1].set_xlabel('Снизилась')
axes[2].set_title('')
axes[2].set_xlabel('Прежний уровень')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))
fig.suptitle('Общее число неоплаченных товаров в корзине за последние 3 месяца')
axes[0].hist(market_file_low['Неоплаченные_продукты_штук_квартал'], alpha=0.5, label='Снизилась')
axes[0].hist(market_file_norm['Неоплаченные_продукты_штук_квартал'], alpha=0.5, label='Прежний уровень')
axes[0].set_xlabel('в штуках')
axes[0].legend(loc='upper right')
axes[1].boxplot(market_file_low['Неоплаченные_продукты_штук_квартал'], vert=False)
axes[2].boxplot(market_file_norm['Неоплаченные_продукты_штук_квартал'], vert=False)
axes[1].set_title('')
axes[1].set_xlabel('Снизилась')
axes[2].set_title('')
axes[2].set_xlabel('Прежний уровень')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))
fig.suptitle('Число сбоев, которые коснулись покупателя во время посещения сайта')
axes[0].hist(market_file_low['Ошибка_сервиса'], alpha=0.5, label='Снизилась')
axes[0].hist(market_file_norm['Ошибка_сервиса'], alpha=0.5, label='Прежний уровень')
axes[0].set_xlabel('в штуках')
axes[0].legend(loc='upper right')
axes[1].boxplot(market_file_low['Ошибка_сервиса'], vert=False)
axes[2].boxplot(market_file_norm['Ошибка_сервиса'], vert=False)
axes[1].set_title('')
axes[1].set_xlabel('Снизилась')
axes[2].set_title('')
axes[2].set_xlabel('Прежний уровень')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,5))
fig.suptitle('Среднее количество страниц, за один визит на сайт за последние 3 месяца')
axes[0].hist(market_file_low['Страниц_за_визит'], alpha=0.5, label='Снизилась')
axes[0].hist(market_file_norm['Страниц_за_визит'], alpha=0.5, label='Прежний уровень')
axes[0].set_xlabel('в штуках')
axes[0].legend(loc='upper right')
axes[1].boxplot(market_file_low['Страниц_за_визит'], vert=False)
axes[2].boxplot(market_file_norm['Страниц_за_визит'], vert=False)
axes[1].set_title('')
axes[1].set_xlabel('Снизилась')
axes[2].set_title('')
axes[2].set_xlabel('Прежний уровень')
plt.show()

# %%
market_file['Покупательская_активность'].value_counts()
# Out:
# Покупательская_активность
# Прежний уровень    802
# Снизилась          498
# Name: count, dtype: int64

# %%
axe = market_file['Покупательская_активность'].value_counts().plot.pie(autopct='%1.1f%%')
axe.set_ylabel('')
plt.title('Рассчитанный класс покупательской активности (целевой признак)')
plt.show()

# %%
market_file['Тип_сервиса'].value_counts()
# Out:
# Тип_сервиса
# стандарт     914
# премиум      376
# стандартт     10
# Name: count, dtype: int64

# %% [markdown]
# обнаружено 2 "разночтения" по факту одной и той же категории в признаке

# %%
market_file['Тип_сервиса'] = market_file['Тип_сервиса'].str.replace('стандартт', 'стандарт')

# %%
market_file_low['Тип_сервиса'] = market_file_low['Тип_сервиса'].str.replace('стандартт', 'стандарт')

# %%
market_file_norm['Тип_сервиса'] = market_file_norm['Тип_сервиса'].str.replace('стандартт', 'стандарт')

# %%
market_file['Тип_сервиса'].value_counts()
# Out:
# Тип_сервиса
# стандарт    924
# премиум     376
# Name: count, dtype: int64

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
fig.suptitle('Соотношение клиентов по подпискам')
ax1.pie(market_file_low['Тип_сервиса'].value_counts(), autopct='%1.1f%%', labels=market_file_low['Тип_сервиса'].value_counts().index)
ax1.set_title('Снизилась')
ax2.pie(market_file_norm['Тип_сервиса'].value_counts(), autopct='%1.1f%%', labels=market_file_low['Тип_сервиса'].value_counts().index)
ax2.set_title('Прежний уровень')
plt.show()

# %%
market_file['Разрешить_сообщать'].value_counts()
# Out:
# Разрешить_сообщать
# да     962
# нет    338
# Name: count, dtype: int64

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
fig.suptitle('Разрешение присылать покупателю дополнительные предложения')
ax1.pie(market_file_low['Разрешить_сообщать'].value_counts(), autopct='%1.1f%%', labels=market_file_low['Разрешить_сообщать'].value_counts().index)
ax1.set_title('Снизилась')
ax2.pie(market_file_norm['Разрешить_сообщать'].value_counts(), autopct='%1.1f%%', labels=market_file_low['Разрешить_сообщать'].value_counts().index)
ax2.set_title('Прежний уровень')
plt.show()

# %%
market_file['Популярная_категория'].value_counts()
# Out:
# Популярная_категория
# Товары для детей                        330
# Домашний текстиль                       251
# Косметика и аксесуары                   223
# Техника для красоты и здоровья          184
# Мелкая бытовая техника и электроника    174
# Кухонная посуда                         138
# Name: count, dtype: int64

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(15,5))
fig.suptitle('Популярная категория товаров у покупателя за последние 6 месяцев')
ax1.pie(market_file_low['Популярная_категория'].value_counts(), autopct='%1.1f%%', labels=market_file_low['Популярная_категория'].value_counts().index)
ax1.set_title('Снизилась')
ax2.pie(market_file_norm['Популярная_категория'].value_counts(), autopct='%1.1f%%', labels=market_file_low['Популярная_категория'].value_counts().index)
ax2.set_title('Прежний уровень')
plt.show()

# %% [markdown]
# **Вывод по разделу:**

# %% [markdown]
# - удалены выбросы
# - исправлены разночтения одной и той же категории в признаке
# - клиенты с уменьшившейся активностью отличаются по cреднему количеству страниц, доли покупок по акциям

# %% [markdown]
# ## Объединение таблиц

# %% [markdown]
# ### Объедините таблицы `market_file.csv`, `market_money.csv`, `market_time.csv`.

# %% [markdown]
# Данные о прибыли из файла money.csv при моделировании вам не понадобятся.

# %%
market_file.shape
# Out:
# (1300, 12)

# %%
market_money.shape
# Out:
# (3893, 2)

# %%
market_time.shape
# Out:
# (2600, 2)

# %%
df = market_file.join(market_money)

# %%
df = pd.merge(df, market_time, left_on=['id', 'Период'], right_on = ['id', 'Период'], how="outer")

# %%
df.shape
# Out:
# (3897, 15)

# %%
df.head(5)
# Out:
#        Покупательская_активность Тип_сервиса Разрешить_сообщать  \
# id
# 215348                       NaN         NaN                NaN
# 215348                 Снизилась     премиум                 да
# 215349                 Снизилась     премиум                 да
# 215349                 Снизилась     премиум                 да
# 215349                 Снизилась     премиум                 да
#
#         Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# id
# 215348                 NaN                   NaN           NaN
# 215348                3.40                  5.00        121.00
# 215349                4.40                  4.00        819.00
# 215349                4.40                  4.00        819.00
# 215349                4.40                  4.00        819.00
#
#         Акционные_покупки Популярная_категория  \
# id
# 215348                NaN                  NaN
# 215348               0.00     Товары для детей
# ...

# %% [markdown]
# ### Учитывайте, что данные о выручке и времени на сайте находятся в одном столбце для всех периодов.

# %% [markdown]
# В итоговой таблице сделайте отдельный столбец для каждого периода.

# %%
market_money_periods = pd.pivot_table(market_money, index='id', columns='Период')

# %%
market_money_periods.columns = ['Выручка_предыдущий_месяц', 'Выручка_препредыдущий_месяц', 'Выручка_текущий_месяц']

# %%
market_money_periods.head(5)
# Out:
#         Выручка_предыдущий_месяц  Выручка_препредыдущий_месяц  \
# id
# 215348                       NaN                          NaN
# 215349                  5,216.00                     4,472.00
# 215350                  5,457.50                     4,826.00
# 215351                  6,158.00                     4,793.00
# 215352                  5,807.50                     4,594.00
#
#         Выручка_текущий_месяц
# id
# 215348               3,293.10
# 215349               4,971.60
# 215350               5,058.40
# 215351               6,610.40
# 215352               5,872.50

# %% [markdown]
# НЕ Заполним пропуски - `0`

# %%
market_time_periods = pd.pivot_table(market_time, index='id', columns='Период')

# %%
market_time_periods.columns = ['Время_предыдущий_месяц', 'Время_текущий_месяц']

# %%
market_time_periods = market_time_periods.fillna(value=0)

# %%
df = market_file.join(market_money_periods).join(market_time_periods)

# %%
df.isna().sum(), df.shape
# Out:
# (Покупательская_активность              0
#  Тип_сервиса                            0
#  Разрешить_сообщать                     0
#  Маркет_актив_6_мес                     0
#  Маркет_актив_тек_мес                   0
#  Длительность                           0
#  Акционные_покупки                      0
#  Популярная_категория                   0
#  Средний_просмотр_категорий_за_визит    0
#  Неоплаченные_продукты_штук_квартал     0
#  Ошибка_сервиса                         0
#  Страниц_за_визит                       0
#  Выручка_предыдущий_месяц               3
#  Выручка_препредыдущий_месяц            3
#  Выручка_текущий_месяц                  1
#  Время_предыдущий_месяц                 0
#  Время_текущий_месяц                    0
#  dtype: int64,
#  (1300, 17))

# %% [markdown]
# Удалим пропуски

# %%
df.dropna(inplace=True)

# %%
df.isna().sum(), df.shape
# Out:
# (Покупательская_активность              0
#  Тип_сервиса                            0
#  Разрешить_сообщать                     0
#  Маркет_актив_6_мес                     0
#  Маркет_актив_тек_мес                   0
#  Длительность                           0
#  Акционные_покупки                      0
#  Популярная_категория                   0
#  Средний_просмотр_категорий_за_визит    0
#  Неоплаченные_продукты_штук_квартал     0
#  Ошибка_сервиса                         0
#  Страниц_за_визит                       0
#  Выручка_предыдущий_месяц               0
#  Выручка_препредыдущий_месяц            0
#  Выручка_текущий_месяц                  0
#  Время_предыдущий_месяц                 0
#  Время_текущий_месяц                    0
#  dtype: int64,
#  (1296, 17))

# %% [markdown]
# **Вывод по разделу:**

# %% [markdown]
# - объединины таблицы market_file.csv, market_money.csv, market_time.csv
# - в итоговой таблице сделаны отдельные столбцы для каждого периода
# - удалено 4 пропуска

# %% [markdown]
# ## Корреляционный анализ

# %% [markdown]
# Проведите корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования. Сделайте выводы о мультиколлинеарности и при необходимости устраните её.

# %%
cat_col_names = df.select_dtypes(exclude='number').columns.tolist()

# %%
num_col_names = df.select_dtypes(include='number').columns.tolist()

# %%
cat_col_names
# Out:
# ['Покупательская_активность',
#  'Тип_сервиса',
#  'Разрешить_сообщать',
#  'Популярная_категория']

# %%
num_col_names
# Out:
# ['Маркет_актив_6_мес',
#  'Маркет_актив_тек_мес',
#  'Длительность',
#  'Акционные_покупки',
#  'Средний_просмотр_категорий_за_визит',
#  'Неоплаченные_продукты_штук_квартал',
#  'Ошибка_сервиса',
#  'Страниц_за_визит',
#  'Выручка_предыдущий_месяц',
#  'Выручка_препредыдущий_месяц',
#  'Выручка_текущий_месяц',
#  'Время_предыдущий_месяц',
#  'Время_текущий_месяц']

# %% [markdown]
# Т.к. признаки распределены не нормально, то считать коэффициенты корреляции будем методом Спирмена

# %%
df.head(5)
# Out:
#        Покупательская_активность Тип_сервиса Разрешить_сообщать  \
# id
# 215349                 Снизилась     премиум                 да
# 215350                 Снизилась    стандарт                нет
# 215351                 Снизилась    стандарт                 да
# 215352                 Снизилась    стандарт                нет
# 215353                 Снизилась    стандарт                 да
#
#         Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# id
# 215349                4.40                     4           819
# 215350                4.90                     3           539
# 215351                3.20                     5           896
# 215352                5.10                     3          1064
# 215353                3.30                     4           762
#
#         Акционные_покупки Популярная_категория  \
# id
# 215349               0.75     Товары для детей
# 215350               0.14    Домашний текстиль
# ...

# %%
corr = df[num_col_names].corr(method='spearman')

# %%
matrix = np.triu(corr)

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", mask=matrix)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Вывод по разделу:**

# %% [markdown]
# - наблюдается очень высокая корреляция (0.88) между `Выручка_предыдущий_месяц`, `Выручка_текущий_месяц`, скорее всего мультиколлинеарности нет
# - утечки данных отсутствуют

# %% [markdown]
# ## Использование пайплайнов

# %% [markdown]
# Примените все изученные модели. Для этого используйте пайплайны.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(['Покупательская_активность'], axis=1),
    df['Покупательская_активность'],
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE,
    stratify = df['Покупательская_активность'])

# %%
X_train.shape, X_test.shape
# Out:
# ((972, 16), (324, 16))

# %%
ohe_columns = X_train.select_dtypes(exclude='number').columns.tolist()

# %%
num_columns = X_train.select_dtypes(include='number').columns.tolist()

# %%
label_encoder = LabelEncoder()

# %%
y_train = label_encoder.fit_transform(y_train)

# %%
y_test = label_encoder.transform(y_test)

# %%
pd.DataFrame(label_encoder.classes_)
# Out:
#                  0
# 0  Прежний уровень
# 1        Снизилась

# %% [markdown]
# ### Во время подготовки данных используйте `ColumnTransformer`. Количественные и категориальные признаки обработайте в пайплайне раздельно. Для кодирования категориальных признаков используйте как минимум два кодировщика, для масштабирования количественных — как минимум два скейлера.

# %% [markdown]
# Напоминаем, что для каждой модели можно подготовить данные с разным кодированием и масштабированием.

# %%
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')), 
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore'))]
)

# %%
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('num', MinMaxScaler(), num_columns)], 
    remainder='passthrough'
)

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %% [markdown]
# ### Обучите четыре модели: `KNeighborsClassifier()`, `DecisionTreeClassifier()`, `LogisticRegression()` и  `SVC()`. Для каждой из них подберите как минимум один гиперпараметр. Выберите подходящую для задачи метрику, аргументируйте свой выбор. Используйте эту метрику при подборе гиперпараметров.

# %% [markdown]
# ### Выберите лучшую модель, используя заданную метрику. Для этого примените одну из стратегий:

# %% [markdown]
# - использовать пайплайны и инструменты подбора гиперпараметров для каждой модели отдельно, чтобы выбрать лучшую модель самостоятельно;
# - использовать один общий пайплайн для всех моделей и инструмент подбора гиперпараметров, который вернёт вам лучшую модель.

# %%
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    }
]

# %% [markdown]
# Т.к. необходимо оценить качество решений модели в наиболее общем виде, учитывая все возможные пороговые значения то выберем метрику ROC-AUC

# %%
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               handle_unknown='ignore'))]),
#                                                                                ['Тип_сервиса',
# ...

# %%
print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   ['Тип_сервиса',
#                                                    'Разрешить_сообщать',
#                                                    'Популярная_категория']),
#                                                  ('num', MinMaxScaler(),
# ...

# %%
print (f'Метрика лучшей модели на тренировочной выборке: {randomized_search.best_score_:.2f}')
# Out:
# Метрика лучшей модели на тренировочной выборке: 0.90

# %%
y_test_pred = randomized_search.predict(X_test)

# %%
model = randomized_search.best_estimator_.named_steps['models']

# %%
preprocessor = randomized_search.best_estimator_.named_steps['preprocessor']

# %%
col_names = preprocessor.get_feature_names_out()

# %%
X_train_new = pd.DataFrame(data=preprocessor.transform(X_train), columns=col_names)

# %%
X_test_new = pd.DataFrame(data=preprocessor.transform(X_test), columns=col_names)

# %%
y_proba = model.predict_proba(X_test_new.to_numpy())[:,1]

# %%
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_proba):.2f}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.92

# %% [markdown]
# **Вывод по разделу:**

# %% [markdown]
# - лучшая модель LogisticRegression(C=4, penalty='l1', random_state=42, solver='liblinear')
# - Т.к. необходимо оценить качество решений модели в наиболее общем виде, учитывая все возможные пороговые значения то выберем метрику ROC-AUC
# - метрика лучшей модели на тренировочной выборке: 0.90
# - метрика ROC-AUC на тестовой выборке: 0.92

# %% [markdown]
# ## Анализ важности признаков

# %% [markdown]
# ### Оцените важность признаков для лучшей модели и постройте график важности с помощью метода SHAP.

# %%
coefficients = model.coef_[0]

# %%
coefficients
# Out:
# array([ 0.0671698 , -0.10497239, -0.17049878, -0.27234684, -1.14999333,
#        -0.62001555, -0.2356559 , -2.41373802,  0.1106989 ,  0.3783378 ,
#         2.20094513, -2.33934526,  2.64575105, -0.58710319, -3.16679131,
#         1.34724306, -1.16270073, -1.14905678, -2.63325383, -2.16426234])

# %%
sns.set_style('white')

# %%
feature_importance = pd.DataFrame({'Feature': X_train_new.columns, 'Importance': np.abs(coefficients)})

# %%
feature_importance = feature_importance.sort_values('Importance', ascending=True)

# %%
feature_importance.plot(x='Feature', y='Importance', kind='barh', figsize=(10, 6))
# Out:
# <AxesSubplot:ylabel='Feature'>

# %%
explainer = shap.LinearExplainer(model, X_test_new)

# %%
shap_values = explainer(X_test_new)

# %%
shap.summary_plot(shap_values, X_test_new, plot_type='bar')

# %%
shap.plots.beeswarm(shap_values, max_display=20)

# %%
shap.plots.waterfall(shap_values[0])

# %% [markdown]
# ### Сделайте выводы о значимости признаков

# %% [markdown]
# - малозначимые признаки: `Популярная_категория`, `Тип_сервиса`, `Разрешить_сообщать`, `Маркет_актив_тек_мес`, `Длительность`, `Ошибка_сервиса`, `Выручка_предыдущий_месяц`, `Выручка_текущий_месяц`
# - сильно влияющие признаки: `Маркет_актив_6_мес`, `Акционные_покупки`, `Средний_просмотр_категорий_за_визит`, `Неоплаченные_продукты_штук_квартал`, `Страниц_за_визит`, `Выручка_препредыдущий_месяц`, `Время_предыдущий_месяц`, `Время_текущий_месяц`

# %% [markdown]
# ## Сегментация покупателей

# %% [markdown]
# Выделите сегмент покупателей, проанализируйте его и предложите, как увеличить его покупательскую активность. Используйте данные моделирования, данные о прибыли покупателей и исходные данные (если понадобятся).
#   - Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.

# %% [markdown]
# ### Выполните сегментацию покупателей. Используйте результаты моделирования и данные о прибыльности покупателей.

# %%
df_new = X_test.copy()

# %%
df_new.shape[0], y_proba.shape[0]
# Out:
# (324, 324)

# %%
df_new['Предсказанная_вероятность'] = y_proba

# %%
df_new.head(5)
# Out:
#        Тип_сервиса Разрешить_сообщать  Маркет_актив_6_мес  \
# id
# 216161    стандарт                 да                4.10
# 215654     премиум                нет                1.40
# 216307     премиум                 да                3.30
# 215501     премиум                 да                3.50
# 215934    стандарт                нет                5.50
#
#         Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# id
# 216161                     4           606               0.15
# 215654                     4           684               0.94
# 216307                     4           488               0.13
# 215501                     3          1057               0.35
# 215934                     4           147               0.99
#
#                         Популярная_категория  \
# id
# 216161        Техника для красоты и здоровья
# 215654                      Товары для детей
# 216307                     Домашний текстиль
# ...

# %%
sns.scatterplot(x='Акционные_покупки', y='Предсказанная_вероятность', data=df_new)
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
axes[0].hist(df_new['Акционные_покупки'], bins=50)
axes[0].set_xlabel('Акционные_покупки')
axes[1].hist(df_new['Предсказанная_вероятность'], bins=50)
axes[1].set_xlabel('Предсказанная_вероятность')
plt.show()

# %%
df_hi = df_new[
    (df_new['Предсказанная_вероятность'] > 0.7) &
    (df_new['Акционные_покупки'] > 0.8)
].copy()

# %%
df_hi.shape[0]
# Out:
# 34

# %%
sns.scatterplot(x='Акционные_покупки', y='Предсказанная_вероятность', data=df_hi)
plt.show()

# %% [markdown]
# ### Выберите группу покупателей и предложите, как увеличить её покупательскую активность:

# %% [markdown]
# - Проведите графическое и аналитическое исследование группы покупателей.
# - Сделайте предложения по работе с сегментом для увеличения покупательской активности.

# %% [markdown]
# Cильно влияющие признаки: `Маркет_актив_6_мес`, `Акционные_покупки`, `Средний_просмотр_категорий_за_визит`, `Неоплаченные_продукты_штук_квартал`, `Страниц_за_визит`, `Выручка_препредыдущий_месяц`, `Время_предыдущий_месяц`, `Время_текущий_месяц`

# %%
top_feature = ['Маркет_актив_6_мес', 'Акционные_покупки', 'Средний_просмотр_категорий_за_визит', 'Неоплаченные_продукты_штук_квартал', 'Страниц_за_визит', 'Выручка_препредыдущий_месяц', 'Время_предыдущий_месяц', 'Время_текущий_месяц']

# %%
for f in top_feature:
    sns.boxplot(data = df_hi, y = f, x='Популярная_категория', showfliers=False, showmeans=True)
    plt.xticks(rotation=90)
    plt.show()

# %%
top_feature.append('Предсказанная_вероятность')
sns.pairplot(df_hi[top_feature], corner=True)
plt.show()

# %% [markdown]
# ### Сделайте выводы о сегментах:

# %% [markdown]
# Для выбранной группы покупателей с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности можно провести следующие действия:
#
# - персонализированные предложения и скидки: данные о предпочтениях и истории покупок клиентов для создания индивидуальных предложений и скидок, которые могут стимулировать их к покупкам
# - программы лояльности: предлагая клиентам бонусы, скидки или подарки за покупки. Это может стать мощным инструментом для удержания клиентов и стимулирования повторных покупок

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Данная работа направлена на увеличение покупательской активности в интернет-магазине "В один клик" путем анализа данных и разработки персонализированных предложений для сегментов покупателей.

# %% [markdown]
# Задача: Цель состояла в разработке модели, способной предсказывать вероятность снижения покупательской активности клиента в следующие три месяца на основе данных о его поведении и финансовых показателях.

# %% [markdown]
# Исходные данные и предобработка: Были получены данные о поведении клиентов на сайте, о выручке, времени на сайте и прибыли компании от каждого клиента. Предобработка данных включала обработку пропусков, преобразование категориальных признаков, а также объединение таблиц.
# - данные в таблицах загружены и соответствуют описанию
# - пропуски отсутствуют
# - аномалии отсутствуют
# - явные дубликаты отсутствуют
# - столбцы приведены к соответствующим типам
# - удалены выбросы
# - исправлены разночтения одной и той же категории в признаке
# - клиенты с уменьшившейся активностью отличаются по cреднему количеству страниц, доли покупок по акциям
# - объединины таблицы market_file.csv, market_money.csv, market_time.csv
# - в итоговой таблице сделаны отдельные столбцы для каждого периода
# - удалено 4 пропуска
# - наблюдается очень высокая корреляция (0.88) между `Выручка_предыдущий_месяц`, `Выручка_текущий_месяц`, скорее всего мультиколлинеарности нет

# %% [markdown]
# Поиск лучшей модели: Были исследованы четыре модели: KNeighborsClassifier, DecisionTreeClassifier, LogisticRegression и SVC. Для каждой модели подбирались гиперпараметры с использованием кросс-валидации.
# - лучшая модель LogisticRegression(C=4, penalty='l1', random_state=42, solver='liblinear')
# - Т.к. необходимо оценить качество решений модели в наиболее общем виде, учитывая все возможные пороговые значения то выберем метрику ROC-AUC
# - метрика лучшей модели на тренировочной выборке: 0.90
# - метрика ROC-AUC на тестовой выборке: 0.92

# %% [markdown]
# Важность признаков: С помощью метода SHAP была оценена важность признаков для лучшей модели. Выявлено, что наибольшее влияние на целевой признак оказывают признаки, связанные с продуктовым и покупательским поведением.
# - малозначимые признаки: `Популярная_категория`, `Тип_сервиса`, `Разрешить_сообщать`, `Маркет_актив_тек_мес`, `Длительность`, `Ошибка_сервиса`, `Выручка_предыдущий_месяц`, `Выручка_текущий_месяц`
# - сильно влияющие признаки: `Маркет_актив_6_мес`, `Акционные_покупки`, `Средний_просмотр_категорий_за_визит`, `Неоплаченные_продукты_штук_квартал`, `Страниц_за_визит`, `Выручка_препредыдущий_месяц`, `Время_предыдущий_месяц`, `Время_текущий_месяц`

# %% [markdown]
# Сегментация покупателей: Проведена сегментация покупателей на основе результатов моделирования и данных о прибыльности. Выбран сегмент клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
# Для выбранной группы покупателей можно провести следующие действия:
# - персонализированные предложения и скидки: данные о предпочтениях и истории покупок клиентов для создания индивидуальных предложений и скидок, которые могут стимулировать их к покупкам
# - программы лояльности: предлагая клиентам бонусы, скидки или подарки за покупки. Это может стать мощным инструментом для удержания клиентов и стимулирования повторных покупок

# %% [markdown]
# Снизить вероятность снижения покупательской активности можно увеличением показателя `Страниц_за_визит`

# %% [markdown]
# Общий вывод: Работа позволила разработать модель, способную предсказывать вероятность снижения покупательской активности клиентов, и выявить персонализированные подходы для стимулирования покупок в выбранном сегменте покупателей. Эти выводы и рекомендации могут быть использованы для оптимизации маркетинговых стратегий и увеличения общей покупательской активности в интернет-магазине "В один клик".
